# %% [markdown]
# This notebook serves as giving a basic peek at a few layers available (45 in total) from the [digital datasets from the Great Artesian Basin](http://www.ga.gov.au/scientific-topics/water/groundwater/gab/digital-datasets-from-the-gab-atlas).

# %%
# %matplotlib inline
import geopandas as gpd

# %%
hydro = gpd.read_file('../81672/GAB_Hydrogeology.shp')

# %%
hydro.plot(figsize=(10,10));

# %%
hydro.ix[0].geometry

# %%
hydro.ix[0]
# Out:
# descript           Great Artesian Basin regional hydrogeology
# geometry    POLYGON ((1229429.924900003 -2826736.0174, 123...
# name                         BirkheadWalloon Aquitard Outcrop
# Name: 0, dtype: object

# %%
sodium = gpd.read_file('../81695/Cadna_owie Hooray_Sodium_DataPoints.shp')

# %%
sodium.plot(figsize=(10,10));

# %%
sodium_kriging = gpd.read_file('../81695/Cadna_owie Hooray_Sodium_PredictedValues_Kriging.shp')

# %%
sodium_kriging.plot(figsize=(10,10));

# %%
sodium_kriging.ix[0].geometry

# %%
sodium_kriging.ix[0]
# Out:
# Classes                                                      2
# Value_Max                                                   60
# Value_Min                                                   40
# geometry     POLYGON ((1430341.86807323 -3685124.405369932,...
# Name: 0, dtype: object
